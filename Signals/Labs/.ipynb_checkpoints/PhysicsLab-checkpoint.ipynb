# %%
import matplotlib.pyplot as pyplot
import numpy as np
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D,axes3d
# %matplotlib notebook

V = np.linspace(0,5,15)

fig = pyplot.figure()
ax = fig.add_subplot(111)

#x = y = np.linspace(-np.pi, np.pi, 200);
x = np.arange(1,14);
y = np.arange(1,10);
X, Y = np.meshgrid(x,y);

zs = np.array([[0.55, 0.77, 1.10, 1.49, 1.91, 2.43, 2.93, 3.46, 3.94, 4.41, 0, 0, 0],
        [0.40, 0.58, 0.93, 1.37, 1.87, 2.42, 2.93, 3.44, 3.95, 4.43, 0, 0, 0],
        [0.20, 0.32, 0.70, 1.24, 1.82, 2.38, 2.91, 3.43, 3.92, 4.41, 0, 0, 0],
        [float('NaN'), 0   , 0.44, 1.14, 1.78, 2.35, 2.90, 3.43, 3.92, 4.41, 0, 0, 0],
        [0   , 0   , 0   , 1.14, 1.84, 2.38, 2.92, 3.42, 3.91, 4.42, 0, 0, 0],
        [0   , 0   , 0.65, 1.32, 1.90, 2.45, 2.94, 3.44, 3.93, 4.40, 0, 0, 0],
        [0.55, 0.73, 1.08, 1.55, 2.03, 2.52, 2.99, 3.46, 3.94, 4.40, 0, 0, 0],
        [0.85, 1.06, 1.35, 1.73, 2.15, 2.60, 3.04, 3.50, 3.94, 4.39, 0, 0, 0],
        [1.08, 1.26, 1.54, 1.88, 2.26, 2.67, 3.67, 3.52, 3.93, 4.35, 0, 0, 0]]);

#zs = np.array([(np.sin(x)*np.sin(y)) for x,y in zip(np.ravel(X), np.ravel(Y))])
Z = zs.reshape(X.shape)
#first graph
ax.contour(X, Y, Z, V, cmap = cm.inferno)

pyplot.show();

#2nd graph
fig = pyplot.figure()
ax = fig.add_subplot(111)
dZx, dZy = np.gradient(Z)

ax.streamplot(X,Y,dZy,dZx, density=3, linewidth=2, color=Z, cmap = cm.inferno)

pyplot.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999630089984">
# <img src="data:image/png;base64,..." width="639.9999630089984">

# %%
print("hello")
# Out:
# hello
